# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/iphone_sales_data.csv")
df.head()
# Out:
#          Date  Sales   Model   Ram    Mrp  Sale Price  Discount Percentage  \
# 0  01-01-2023     34  12 Pro  2 GB  49900       49700                  200
# 1  01-03-2023     16  13 Pro  4 GB  84900       84800                  100
# 2  01-06-2023     39  14 Pro  6 GB  84900       83900                 1000
# 3  01-09-2023     79  15 Pro  8 GB  77000       76000                 1000
# 4  01-11-2023     50  12 Pro  2 GB  77000       76900                  100
#
#    Star Rating
# 0          4.6
# 1          4.6
# 2          4.6
# 3          4.5
# 4          4.5

# %%
df.shape
# Out:
# (129, 8)

# %%
print(df.dtypes)
# Out:
# Date                    object
# Sales                    int64
# Model                   object
# Ram                     object
# Mrp                      int64
# Sale Price               int64
# Discount Percentage      int64
# Star Rating            float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129 entries, 0 to 128
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 129 non-null    object
#  1   Sales                129 non-null    int64
#  2   Model                129 non-null    object
#  3   Ram                  129 non-null    object
#  4   Mrp                  129 non-null    int64
#  5   Sale Price           129 non-null    int64
#  6   Discount Percentage  129 non-null    int64
#  7   Star Rating          129 non-null    float64
# dtypes: float64(1), int64(4), object(3)
# memory usage: 8.2+ KB

# %%
print(df.isnull().sum())
# Out:
# Date                   0
# Sales                  0
# Model                  0
# Ram                    0
# Mrp                    0
# Sale Price             0
# Discount Percentage    0
# Star Rating            0
# dtype: int64

# %%
df.describe()
# Out:
#             Sales            Mrp     Sale Price  Discount Percentage  \
# count  129.000000     129.000000     129.000000           129.000000
# mean    69.953488   88466.837209   83537.279070          4929.558140
# std     18.965784   34100.529551   30073.087929          6229.761044
# min     16.000000   30000.000000   29000.000000             0.000000
# 25%     56.000000   67000.000000   65800.000000           800.000000
# 50%     72.000000   80059.000000   78200.000000          1000.000000
# 75%     87.000000  120500.000000  110900.000000          9000.000000
# max     98.000000  159999.000000  153599.000000         22400.000000
#
#        Star Rating
# count   129.000000
# mean      4.525581
# std       0.205882
# min       4.000000
# 25%       4.500000
# 50%       4.600000
# 75%       4.600000
# max       4.900000

# %%
df.head()
# Out:
#          Date  Sales   Model   Ram    Mrp  Sale Price  Discount Percentage  \
# 0  01-01-2023     34  12 Pro  2 GB  49900       49700                  200
# 1  01-03-2023     16  13 Pro  4 GB  84900       84800                  100
# 2  01-06-2023     39  14 Pro  6 GB  84900       83900                 1000
# 3  01-09-2023     79  15 Pro  8 GB  77000       76000                 1000
# 4  01-11-2023     50  12 Pro  2 GB  77000       76900                  100
#
#    Star Rating
# 0          4.6
# 1          4.6
# 2          4.6
# 3          4.5
# 4          4.5

# %%
srt_cols=df.columns[(df.dtypes=="object").tolist()].tolist()
num_cols=df.columns[(df.dtypes!="object").tolist()].tolist()
num_cols
# Out:
# ['Sales', 'Mrp', 'Sale Price', 'Discount Percentage', 'Star Rating']

# %%
srt_cols
# Out:
# ['Date', 'Model', 'Ram']

# %%
# Plotting iPhone sales over time
df['Date'] = pd.to_datetime(df['Date'])  # Assuming the date column is not in datetime format
plt.figure(figsize=(10, 6))
plt.plot(df['Date'], df['Sales'])
plt.title('iPhone Sales Over Time(2023)')
plt.xlabel('Date')
plt.ylabel('Sales')
plt.grid(True)
plt.show()

# %%
df['Date'] = pd.to_datetime(df['Date'])  # Assuming the date column is not in datetime format
plt.figure(figsize=(10, 6))
plt.bar(df['Date'], df['Sales'], width=5)
plt.title('iPhone Sales Over Time(2023)')
plt.xlabel('Date')
plt.ylabel('Sales')
plt.grid(True)
plt.show()

# %%
# Monthly sales trend
df['Month'] = df['Date'].dt.to_period('M')
monthly_sales = df.groupby('Month')['Sales'].sum()
plt.figure(figsize=(10, 6))
monthly_sales.plot(kind='bar', color='red')
plt.title('Monthly iPhone Sales Trend(2023)')
plt.xlabel('Month')
plt.ylabel('Sales')
plt.show()

# %%
# Sales distribution by model
plt.figure(figsize=(12, 6))
df['Model'].value_counts().plot(kind='bar', color='green')
plt.title('iPhone Sales Distribution by Model(2023)')
plt.xlabel('Model')
plt.ylabel('Number of Sales')
plt.show()

# %%
plt.scatter(df['Model'], df['Ram'], color='r')
plt.title("")
plt.xlabel('models')
plt.ylabel("Ram")
plt.show()

# %%
plt.bar(df['Model'], df['Discount Percentage'], color='red')
plt.title("Max_Discounts")
plt.xlabel('Models')
plt.ylabel("discount AMT")
plt.show()

# %%
df
# Out:
#            Date  Sales   Model   Ram     Mrp  Sale Price  Discount Percentage  \
# 0    01-01-2023     34  12 Pro  2 GB   49900       49700                  200
# 1    01-03-2023     16  13 Pro  4 GB   84900       84800                  100
# 2    01-06-2023     39  14 Pro  6 GB   84900       83900                 1000
# 3    01-09-2023     79  15 Pro  8 GB   77000       76000                 1000
# 4    01-11-2023     50  12 Pro  2 GB   77000       76900                  100
# ..          ...    ...     ...   ...     ...         ...                  ...
# 124  12-21-2023     87  15 Pro  6 GB   87970       86970                 1000
# 125  12-24-2023     67  14 Pro  6 GB   88900       88600                  300
# 126  12-27-2023     67  12 Pro  4 GB   70042       69242                  800
# 127  12-29-2023     87  15 Pro  6 GB  123500      112700                10800
# 128  12-31-2023     98  14 Pro  4 GB   98009       97209                  800
#
#      Star Rating
# ...

# %%
# Ram vs Sales

from matplotlib import pyplot as plt
import seaborn as sns
figsize = (12, 1.2 * len(df['Ram'].unique()))
plt.figure(figsize=figsize)
sns.violinplot(df, x='Sales', y='Ram', inner='stick', palette='Dark2')
sns.despine(top=True, right=True, bottom=True, left=True)
# Out:
# <ipython-input-19-f917b3abed5b>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(df, x='Sales', y='Ram', inner='stick', palette='Dark2')

# %%
#  Sale Price vs Discount Percentage

from matplotlib import pyplot as plt
df.plot(kind='scatter', x='Sale Price', y='Discount Percentage', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
#Average sales price by RAM size

sns.barplot(data=df, x="Ram", y="Sale Price")
# Out:
# <Axes: xlabel='Ram', ylabel='Sale Price'>

# %%
#  Sales vs Mrp

from matplotlib import pyplot as plt
df.plot(kind='scatter', x='Model', y='Mrp', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
#  Model vs Ram

from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
plt.subplots(figsize=(8, 8))
df_2dhist = pd.DataFrame({
    x_label: grp['Ram'].value_counts()
    for x_label, grp in df.groupby('Model')
})
sns.heatmap(df_2dhist, cmap='viridis')
plt.xlabel('Model')
_ = plt.ylabel('Ram')

# %%
#  Ram

from matplotlib import pyplot as plt
import seaborn as sns
df.groupby('Ram').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
#  Date vs Sales

from matplotlib import pyplot as plt
import seaborn as sns
def _plot_series(series, series_name, series_index=0):
  from matplotlib import pyplot as plt
  import seaborn as sns
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['Date']
  ys = series['Sales']

  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = df.sort_values('Date', ascending=True)
for i, (series_name, series) in enumerate(df_sorted.groupby('Model')):
  _plot_series(series, series_name, i)
  fig.legend(title='Model', bbox_to_anchor=(1, 1), loc='upper left')
sns.despine(fig=fig, ax=ax)
plt.xlabel('Date')
_ = plt.ylabel('Sales')
